# %%
import pandas as pd
import numpy as np
from glob import iglob

# %%
# !ls ../DeepTrader/data/DJIA
# Out:
# data_fetch.ipynb  djia_stocks  djia_stocks.csv	industry_classification.npy

# %%
df_desp = pd.read_csv("../DeepTrader/data/DJIA/djia_stocks.csv")

# %%
data_fpath = [i for i in iglob("../DeepTrader/data/DJIA/djia_stocks/*.csv")]

# %%
df_stocks = pd.read_csv(data_fpath[1], index_col=0)

# %%
df_stocks
# Out:
#             Date    Open     Low    High   Close  Adj. Close    Volume  \
# 0     2007-01-03   68.42   67.85   69.48   68.40       51.66  12908400
# 1     2007-01-04   69.48   68.97   71.87   71.33       53.87  16000900
# 2     2007-01-05   71.34   71.01   72.08   71.50       54.00  10462000
# 3     2007-01-08   71.63   70.79   71.89   70.93       53.57   6747100
# 4     2007-01-09   71.17   70.67   71.68   71.27       53.82   7165200
# ...          ...     ...     ...     ...     ...         ...       ...
# 3985  2022-10-31  269.20  268.00  271.81  270.35      270.35   3031003
# 3986  2022-11-01  269.60  268.38  272.87  272.06      272.06   2062119
# 3987  2022-11-02  271.64  268.95  274.88  269.01      269.01   2636503
# 3988  2022-11-03  268.53  265.02  268.60  265.88      265.88   2764696
# 3989  2022-11-04  261.94  259.84  269.30  269.04      269.04   3401263
#
#       Shares Outstanding  Dividend Yield  Earnings Yield  FCF Yield  \
# ...

# %%
df_stocks["Shares Outstanding"].isna().sum() / df_stocks["Shares Outstanding"].size
# Out:
# 0.0
